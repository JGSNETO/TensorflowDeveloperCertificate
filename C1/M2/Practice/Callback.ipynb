# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
fmnist = tf.keras.datasets.fashion_mnist

# %%
(training_images, training_labels), (test_images, test_labels) = fmnist.load_data()

# %%
class myCallbacks(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs = {}):
        if(logs.get('accuracy') >= 0.6):
            print("\nReached 60% accuracy so stopping training!")
            self.model.stop_training = True

callbacks = myCallbacks()

# %%
training_images = training_images/255
test_images = test_images/255

# %%
model = tf.keras.models.Sequential([tf.keras.layers.Flatten(),
                                    tf.keras.layers.Dense(512, activation=tf.nn.relu),
                                    tf.keras.layers.Dense(10, activation=tf.nn.softmax)
                                    ])

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(training_images, training_labels, epochs=10, callbacks = [callbacks])
# Out:
# Epoch 1/10
# 1870/1875 [============================>.] - ETA: 0s - loss: 0.4794 - accuracy: 0.8292
# Reached 60% accuracy so stopping training!
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.4792 - accuracy: 0.8292

# %%
model.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4117 - accuracy: 0.8523
# [0.4117186665534973, 0.8522999882698059]
