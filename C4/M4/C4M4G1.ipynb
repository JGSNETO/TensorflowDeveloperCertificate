# %% [markdown]
# # Neural Network and TensorFlow Quiz Answers
#
# ## Question 1: You used a sunspots dataset that was stored in CSV. What’s the name of the Python library used to read CSVs?
#
# - **Alternatives:**
#   1. py_csv
#   2. CommaSeparatedValues
#   3. py_files
#   4. csv
#
# - **Answer:** csv
#
# ---
#
# ## Question 2: Why is MAE a good analytic for measuring accuracy of predictions for time series?
#
# - **Alternatives:**
#   1. It doesn’t heavily punish larger errors like square errors do
#   2. It punishes larger errors
#   3. It biases towards small errors
#   4. It only counts positive errors
#
# - **Answer:** It doesn’t heavily punish larger errors like square errors do
#
# ---
#
# ## Question 3: What is the expected input shape for a univariate time series to a Conv1D?
#
# - **Alternatives:**
#   1. (1,)
#   2. (window_size, 1)
#   3. ()
#   4. (1, window_size)
#
# - **Answer:** (window_size, 1)
#
# ---
#
# ## Question 4: When you read a row from a reader and want to cast column 2 to another data type, for example, a float, what’s the correct syntax?
#
# - **Alternatives:**
#   1. float f = row[2].read()
#   2. float(row[2])
#   3. Convert.toFloat(row[2])
#   4. You can’t. It needs to be read into a buffer and a new float instantiated from the buffer
#
# - **Answer:** float(row[2])
#
# ---
#
# ## Question 5: How do you add a 1 dimensional convolution to your model for predicting time series data?
#
# - **Alternatives:**
#   1. Use a 1DConv layer type
#   2. Use a 1DConvolution layer type
#   3. Use a Conv1D layer type
#   4. Use a ConvolutionD1 layer type
#
# - **Answer:** Use a Conv1D layer type
#
# ---
#
# ## Question 6: If your CSV file has a header that you don’t want to read into your dataset, what do you execute before iterating through the file using a ‘reader’ object?
#
# - **Alternatives:**
#   1. next(reader)
#   2. reader.ignore_header()
#   3. reader.read(next)
#   4. reader.next
#
# - **Answer:** next(reader)
#
# ---
#
# ## Question 7: After studying this course, what neural network type do you think is best for predicting time series like our sunspots dataset?
#
# - **Alternatives:**
#   1. RNN / LSTM
#   2. Convolutions
#   3. DNN
#   4. A combination of all other answers
#
# - **Answer:** RNN / LSTM
