# %% [markdown]
# # Neural Network and TensorFlow Quiz Answers
#
# ## Question 1: What’s the primary difference between a simple RNN and an LSTM?
#
# - **Alternatives:**
#   1. LSTMs have a single output, RNNs have multiple
#   2. In addition to the H output, RNNs have a cell state that runs across all cells
#   3. In addition to the H output, LSTMs have a cell state that runs across all cells
#   4. LSTMs have multiple outputs, RNNs have a single one
#
# - **Answer:** In addition to the H output, LSTMs have a cell state that runs across all cells.
#
# ---
#
# ## Question 2: If you want to clear out all temporary variables that tensorflow might have from previous sessions, what code do you run?
#
# - **Alternatives:**
#   1. `tf.cache.backend.clear_session()`
#   2. `tf.keras.clear_session`
#   3. `tf.cache.clear_session()`
#   4. `tf.keras.backend.clear_session()`
#
# - **Answer:** `tf.keras.backend.clear_session()`
#
# ---
#
# ## Question 3: What does a Lambda layer in a neural network do?
#
# - **Alternatives:**
#   1. Changes the shape of the input or output data
#   2. Allows you to execute arbitrary code while training
#   3. There are no Lambda layers in a neural network
#   4. Pauses training without a callback
#
# - **Answer:** Allows you to execute arbitrary code while training.
#
# ---
#
# ## Question 4: If X is the standard notation for the input to an RNN, what are the standard notations for the outputs?
#
# - **Alternatives:**
#   1. Y
#   2. H
#   3. Y(hat) and H
#   4. H(hat) and Y
#
# - **Answer:** H
#
# ---
#
# ## Question 5: A new loss function was introduced in this module, named after a famous statistician. What is it called?
#
# - **Alternatives:**
#   1. Hubble loss
#   2. Hawking loss
#   3. Hyatt loss
#   4. Huber loss
#
# - **Answer:** Huber loss
#
# ---
#
# ## Question 6: What is a sequence to vector if an RNN has 30 cells numbered 0 to 29?
#
# - **Alternatives:**
#   1. The average Y(hat) for all 30 cells
#   2. The Y(hat) for the second cell
#   3. The total Y(hat) for all cells
#   4. The Y(hat) for the last cell
#
# - **Answer:** The Y(hat) for the last cell.
#
# ---
#
# ## Question 7: What does the axis parameter of tf.expand_dims do?
#
# - **Alternatives:**
#   1. Defines if the tensor is X or Y
#   2. Defines the dimension index at which you will expand the shape of the tensor
#   3. Defines the dimension index to remove when you expand the tensor
#   4. Defines the axis around which to expand the dimensions
#
# - **Answer:** Defines the dimension index at which you will expand the shape of the tensor.
#
# ---
#
# ## Question 8: What happens if you define a neural network with these three layers?
#
# ```python
# tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
# tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
# tf.keras.layers.Dense(1),
